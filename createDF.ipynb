# %%
import pandas as pd
import csv
import seaborn as sns
import matplotlib as plt
from datetime import datetime
import numpy as np

# %%
dfData = pd.read_csv('Data/indexData.csv')
dfInfo = pd.read_csv('Data/indexInfo.csv')
dfProcessed = pd.read_csv('Data/indexProcessed.csv')

# %%
from datetime import datetime
dfProcessed2 = dfProcessed.copy()
format1 ="%Y-%m-%d"
format2 = "%m-%Y"
dfProcessed2["Date"] = dfProcessed2["Date"].apply(lambda x: datetime.strptime(x, format1).strftime(format2))

# %%
recessionUS = ['07-1990-03-1991', '03-2001-11-2001', '12-2007-06-2009', '02-2020-04-2020']
recessionJapan  = ['04-1993-07-1993', '01-1992-04-1992', '04-2001-07-2001', '04-2008-01-2009', '10-2010-04-2011', '04-2012-11-2012','08-2018-11-2018', '08-2019-11-2019']
recessionChina = []
recessionCanada = ['03-1990-04-1990','10-2008-05-2009','03-2020-08-2020']
recessionIndia = []
recessionGermany = ['05-1991-08-1991', '05-1991-08-1991', '05-1992-02-1993', '05-2001-02-2002', '11-2002-02-2003', '08-2008-02-2009', '11-2012-02-2013','02-2020-05-2020']
recessionKorea = ['11-1997-05-1998', '02-2003-05-2003', '02-2020-05-2020']
recessionSwitzerland = ['08-1990-11-1990', '05-1991-08-1991', '05-1992-02-1993', '05-1996-08-1996', '11-2002-05-2003','08-2008-11-2008', '02-2020-05-2020']
recessionTaiwan = []
recessionEurope = ['05-2008-02-2009', '11-2011-02-2013','02-2020-05-2020', '11-2020-02-2021']
recessionSouthAfrica = ['05-1990-08-1990', '02-1991-05-1991', '11-1991-11-1992', '11-2008-05-2009']


dfRecessionDates = pd.DataFrame(columns=['US','Japan','Canada','India', 'Germany', 'Korea', 'Switzerland', 'Europe', 'SouthAfrica'])

# %%
import datetime
isRecession = []
for i in range(len(dfProcessed2)):
    if dfProcessed2['Index'][i] == 'NYA' or dfProcessed2['Index'][i] == 'IXIC':
        for p in range(len(recessionUS)):
            range1 = recessionUS[p][:-8]
            range2 = recessionUS[p][8:]
            TODAY_CHECK = datetime.datetime.strptime(dfProcessed2['Date'][i], "%m-%Y")
            start = datetime.datetime.strptime(range1, "%m-%Y")
            end = datetime.datetime.strptime(range2, "%m-%Y")
            if start <= TODAY_CHECK <= end:
                isRecession.append('1.0')
                break
        else:
            isRecession.append('0.0')

    if dfProcessed2['Index'][i] == 'HSI' or dfProcessed2['Index'][i] == '000001.SS' or dfProcessed2['Index'][i] == '399001.SZ':
        for p in range(len(recessionChina)):
            range1 = recessionChina[p][:-8]
            range2 = recessionChina[p][8:]
            TODAY_CHECK = datetime.datetime.strptime(dfProcessed2['Date'][i], "%m-%Y")
            start = datetime.datetime.strptime(range1, "%m-%Y")
            end = datetime.datetime.strptime(range2, "%m-%Y")
            if start <= TODAY_CHECK <= end:
                isRecession.append('1.0')
                break
        else:
            isRecession.append('0.0')

    if dfProcessed2['Index'][i] == 'N225':
        for p in range(len(recessionJapan)):
            range1 = recessionJapan[p][:-8]
            range2 = recessionJapan[p][8:]
            TODAY_CHECK = datetime.datetime.strptime(dfProcessed2['Date'][i], "%m-%Y")
            start = datetime.datetime.strptime(range1, "%m-%Y")
            end = datetime.datetime.strptime(range2, "%m-%Y")
            if start <= TODAY_CHECK <= end:
                isRecession.append('1.0')
                break
        else:
            isRecession.append('0.0')

    if dfProcessed2['Index'][i] == 'N100':
        for p in range(len(recessionEurope)):
            range1 = recessionEurope[p][:-8]
            range2 = recessionEurope[p][8:]
            TODAY_CHECK = datetime.datetime.strptime(dfProcessed2['Date'][i], "%m-%Y")
            start = datetime.datetime.strptime(range1, "%m-%Y")
            end = datetime.datetime.strptime(range2, "%m-%Y")
            if start <= TODAY_CHECK <= end:
                isRecession.append('1.0')
                break
        else:
            isRecession.append('0.0')

    if dfProcessed2['Index'][i] == 'GSPTSE':
        for p in range(len(recessionCanada)):
            range1 = recessionCanada[p][:-8]
            range2 = recessionCanada[p][8:]
            TODAY_CHECK = datetime.datetime.strptime(dfProcessed2['Date'][i], "%m-%Y")
            start = datetime.datetime.strptime(range1, "%m-%Y")
            end = datetime.datetime.strptime(range2, "%m-%Y")
            if start <= TODAY_CHECK <= end:
                isRecession.append('1.0')
                break
        else:
            isRecession.append('0.0')

    if dfProcessed2['Index'][i] == 'NSEI':
        for p in range(len(recessionIndia)):
            range1 = recessionIndia[p][:-8]
            range2 = recessionIndia[p][8:]
            TODAY_CHECK = datetime.datetime.strptime(dfProcessed2['Date'][i], "%m-%Y")
            start = datetime.datetime.strptime(range1, "%m-%Y")
            end = datetime.datetime.strptime(range2, "%m-%Y")
            if start <= TODAY_CHECK <= end:
                isRecession.append('1.0')
                break
        else:
            isRecession.append('0.0')

    if dfProcessed2['Index'][i] == 'GDAXI':
        for p in range(len(recessionGermany)):
            range1 = recessionGermany[p][:-8]
            range2 = recessionGermany[p][8:]
            TODAY_CHECK = datetime.datetime.strptime(dfProcessed2['Date'][i], "%m-%Y")
            start = datetime.datetime.strptime(range1, "%m-%Y")
            end = datetime.datetime.strptime(range2, "%m-%Y")
            if start <= TODAY_CHECK <= end:
                isRecession.append('1.0')
                break
        else:
            isRecession.append('0.0')

    if dfProcessed2['Index'][i] == 'KS11':
        for p in range(len(recessionKorea)):
            range1 = recessionKorea[p][:-8]
            range2 = recessionKorea[p][8:]
            TODAY_CHECK = datetime.datetime.strptime(dfProcessed2['Date'][i], "%m-%Y")
            start = datetime.datetime.strptime(range1, "%m-%Y")
            end = datetime.datetime.strptime(range2, "%m-%Y")
            if start <= TODAY_CHECK <= end:
                isRecession.append('1.0')
                break
        else:
            isRecession.append('0.0')

    if dfProcessed2['Index'][i] == 'SSMI':
        for p in range(len(recessionSwitzerland)):
            range1 = recessionSwitzerland[p][:-8]
            range2 = recessionSwitzerland[p][8:]
            TODAY_CHECK = datetime.datetime.strptime(dfProcessed2['Date'][i], "%m-%Y")
            start = datetime.datetime.strptime(range1, "%m-%Y")
            end = datetime.datetime.strptime(range2, "%m-%Y")
            if start <= TODAY_CHECK <= end:
                isRecession.append('1.0')
                break
        else:
            isRecession.append('0.0')

    if dfProcessed2['Index'][i] == 'TWII':
        for p in range(len(recessionTaiwan)):
            range1 = recessionTaiwan[p][:-8]
            range2 = recessionTaiwan[p][8:]
            TODAY_CHECK = datetime.datetime.strptime(dfProcessed2['Date'][i], "%m-%Y")
            start = datetime.datetime.strptime(range1, "%m-%Y")
            end = datetime.datetime.strptime(range2, "%m-%Y")
            if start <= TODAY_CHECK <= end:
                isRecession.append('1.0')
                break
        else:
            isRecession.append('0.0')

    if dfProcessed2['Index'][i] == 'J203.JO':
        for p in range(len(recessionSouthAfrica)):
            range1 = recessionSouthAfrica[p][:-8]
            range2 = recessionSouthAfrica[p][8:]
            TODAY_CHECK = datetime.datetime.strptime(dfProcessed2['Date'][i], "%m-%Y")
            start = datetime.datetime.strptime(range1, "%m-%Y")
            end = datetime.datetime.strptime(range2, "%m-%Y")
            if start <= TODAY_CHECK <= end:
                isRecession.append('1.0')
                break
        else:
            isRecession.append('0.0')


dfRecession = pd.DataFrame(isRecession)

# %%
dfRecession.columns = ['isRecession']

# %%
dfProcessed2 = pd.concat([dfProcessed, dfRecession], axis=1)

# %%
isUpOrDown = []

for i in range(len(dfProcessed2)):
    if i ==0:
        isUpOrDown.append('0.0')
    else:
        if dfProcessed2['CloseUSD'][i-1] >= dfProcessed2['CloseUSD'][i]:
            isUpOrDown.append('0.0')

        #if dfProcessed2['CloseUSD'][i-1] <= dfProcessed2['CloseUSD'][i]:
        else:
            isUpOrDown.append('1.0')



dfUpOrDown = pd.DataFrame(isUpOrDown)
dfUpOrDown.columns = ['isUpOrDown']

# %%
dfProcessed2 = pd.concat([dfProcessed2, dfUpOrDown], axis=1)

# %%
dfProcessed2['Date'] = pd.to_datetime(dfProcessed2['Date'], format='%Y-%m-%d')

# %%
from pandas.core.groupby import GroupBy

dfProcessedGrouped = dfProcessed2.copy()

dfProcessedGrouped2 = dfProcessedGrouped.groupby('Index')

for key, item in dfProcessedGrouped2:
    print(dfProcessedGrouped2.get_group(key), "\n\n")
#dfProcessedGrouped.get_group('HSI')
# Out:
#            Index       Date         Open         High          Low  \
# 35129  000001.SS 1997-07-02  1255.909058  1261.571045  1147.331055
# 35130  000001.SS 1997-07-03  1194.676025  1194.676025  1149.939941
# 35131  000001.SS 1997-07-04  1138.921021  1163.249023  1124.776001
# 35132  000001.SS 1997-07-07  1161.707031  1163.447021  1085.572021
# 35133  000001.SS 1997-07-08  1092.798950  1115.432983  1066.043945
# ...          ...        ...          ...          ...          ...
# 40915  000001.SS 2021-05-25  3502.540039  3584.580078  3502.439941
# 40916  000001.SS 2021-05-26  3586.840088  3603.489990  3585.370117
# 40917  000001.SS 2021-05-27  3585.729980  3626.360107  3579.260010
# 40918  000001.SS 2021-05-28  3610.770020  3622.179932  3582.360107
# 40919  000001.SS 2021-05-31  3600.070068  3615.659912  3580.649902
#
#              Close    Adj Close    Volume    CloseUSD isRecession isUpOrDown
# 35129  1199.061035  1199.061035       0.0  191.849766         0.0        0.0
# ...

# %%
import matplotlib as plt
ax = dfProcessedGrouped2.plot(x='Date', y='CloseUSD', title='Text')

# %%
dfStudy = dfProcessed2[['CloseUSD','Volume','High','Low','Open','Close','isRecession','isUpOrDown']]

# %%
dfStudy.to_csv('finalDataStudy3.csv')

# %% [markdown]
# Scaling Data

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
main_df_copy = main_df.copy()
# fit_transform
main_df_copy = scaler.fit_transform(main_df_copy)
main_df_copy.shape

# %% [markdown]
# BoxPlot

# %%
plt.figure(figsize=(14,8))
sns.boxplot(data = main_df_copy)
plt.xticks(rotation=90)
plt.show()
